# %% [markdown]
# <a href="https://colab.research.google.com/github/Reinaldos/Reinaldos/blob/main/Imdb_Resilia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab import files
import io
import matplotlib.pyplot as plt
import seaborn as sns

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8aea10cc-2360-4d5b-af0e-40de48ac62ae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8aea10cc-2360-4d5b-af0e-40de48ac62ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving MovieAssignmentData.csv to MovieAssignmentData.csv

# %%
movies = pd.read_csv(io.StringIO(uploaded['MovieAssignmentData.csv'].decode('utf-8')))
movies.shape
# Out:
# (100, 62)

# %%
movies
# Out:
#                                            Title  title_year     budget  \
# 0                                     La La Land        2016   30000000
# 1                                       Zootopia        2016  150000000
# 2                                           Lion        2016   12000000
# 3                                        Arrival        2016   47000000
# 4                          Manchester by the Sea        2016    9000000
# ..                                           ...         ...        ...
# 95                                      Whiplash        2014    3300000
# 96                               Before Midnight        2013    3000000
# 97    Star Wars: Episode VII - The Force Awakens        2015  245000000
# 98  Harry Potter and the Deathly Hallows: Part I        2010  150000000
# 99                       Tucker and Dale vs Evil        2010    5000000
#
#         Gross              actor_1_name        actor_2_name  \
# ...

# %%
movies.columns
# Out:
# Index(['Title', 'title_year', 'budget', 'Gross', 'actor_1_name',
#        'actor_2_name', 'actor_3_name', 'actor_1_facebook_likes',
#        'actor_2_facebook_likes', 'actor_3_facebook_likes', 'IMDb_rating',
#        'genre_1', 'genre_2', 'genre_3', 'MetaCritic', 'Runtime', 'CVotes10',
#        'CVotes09', 'CVotes08', 'CVotes07', 'CVotes06', 'CVotes05', 'CVotes04',
#        'CVotes03', 'CVotes02', 'CVotes01', 'CVotesMale', 'CVotesFemale',
#        'CVotesU18', 'CVotesU18M', 'CVotesU18F', 'CVotes1829', 'CVotes1829M',
#        'CVotes1829F', 'CVotes3044', 'CVotes3044M', 'CVotes3044F', 'CVotes45A',
#        'CVotes45AM', 'CVotes45AF', 'CVotes1000', 'CVotesUS', 'CVotesnUS',
#        'VotesM', 'VotesF', 'VotesU18', 'VotesU18M', 'VotesU18F', 'Votes1829',
#        'Votes1829M', 'Votes1829F', 'Votes3044', 'Votes3044M', 'Votes3044F',
#        'Votes45A', 'Votes45AM', 'Votes45AF', 'Votes1000', 'VotesUS',
#        'VotesnUS', 'content_rating', 'Country'],
#       dtype='object')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    int64
#  3   Gross                   100 non-null    int64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
# ...

# %%
movies.describe(include ='all')
# Out:
#              Title   title_year        budget         Gross  \
# count          100   100.000000  1.000000e+02  1.000000e+02
# unique         100          NaN           NaN           NaN
# top     La La Land          NaN           NaN           NaN
# freq             1          NaN           NaN           NaN
# mean           NaN  2012.820000  7.838400e+07  1.468679e+08
# std            NaN     1.919491  7.445295e+07  1.454004e+08
# min            NaN  2010.000000  3.000000e+06  2.238380e+05
# 25%            NaN  2011.000000  1.575000e+07  4.199752e+07
# 50%            NaN  2013.000000  4.225000e+07  1.070266e+08
# 75%            NaN  2014.000000  1.500000e+08  2.107548e+08
# max            NaN  2016.000000  2.600000e+08  9.366622e+08
#
#              actor_1_name actor_2_name   actor_3_name  actor_1_facebook_likes  \
# count                 100          100            100              100.000000
# unique                 75           94             96                     NaN
# ...

# %% [markdown]
# QUAL O FILME QUE DEU MAIS LUCRO???

# %%
movies = df_imdb.assign(profit = df_imdb['Gross'] - df_imdb['budget'])

movies.nlargest(columns='profit', n=5)[['Title', 'profit']]
# Out:
#                                          Title     profit
# 97  Star Wars: Episode VII - The Force Awakens  691662225
# 11                                The Avengers  403279547
# 47                                    Deadpool  305024263
# 32             The Hunger Games: Catching Fire  294645577
# 12                                 Toy Story 3  214984497

# %%
movies.columns
# Out:
# Index(['Title', 'title_year', 'budget', 'Gross', 'actor_1_name',
#        'actor_2_name', 'actor_3_name', 'actor_1_facebook_likes',
#        'actor_2_facebook_likes', 'actor_3_facebook_likes', 'IMDb_rating',
#        'genre_1', 'genre_2', 'genre_3', 'MetaCritic', 'Runtime', 'CVotes10',
#        'CVotes09', 'CVotes08', 'CVotes07', 'CVotes06', 'CVotes05', 'CVotes04',
#        'CVotes03', 'CVotes02', 'CVotes01', 'CVotesMale', 'CVotesFemale',
#        'CVotesU18', 'CVotesU18M', 'CVotesU18F', 'CVotes1829', 'CVotes1829M',
#        'CVotes1829F', 'CVotes3044', 'CVotes3044M', 'CVotes3044F', 'CVotes45A',
#        'CVotes45AM', 'CVotes45AF', 'CVotes1000', 'CVotesUS', 'CVotesnUS',
#        'VotesM', 'VotesF', 'VotesU18', 'VotesU18M', 'VotesU18F', 'Votes1829',
#        'Votes1829M', 'Votes1829F', 'Votes3044', 'Votes3044M', 'Votes3044F',
#        'Votes45A', 'Votes45AM', 'Votes45AF', 'Votes1000', 'VotesUS',
#        'VotesnUS', 'content_rating', 'Country', 'profit',
# ...

# %%
#Plot profit vs budget
plt.figure(figsize= [10,6])
plt.scatter(movies["budget"], movies["profit"], alpha = 0.5)
plt.title("lucro v/s orçamento\n", fontdict={'fontsize': 20, 'fontweight' : 5, 'color' : 'green'})
plt.xlabel("orçamento em milhões $", fontdict={'fontsize': 12, 'fontweight' : 5, 'color' : '#bb0a1e'})
plt.ylabel("lucro em milhões $", fontdict={'fontsize': 12, 'fontweight' : 5, 'color' : '#bb0a1e'} )
plt.show()

# %%
movies["5_melhores_trios"] = movies["actor_1_facebook_likes"] + movies["actor_2_facebook_likes"] + movies["actor_3_facebook_likes"]

# %%
movies.head()
# Out:
#                    Title  title_year     budget      Gross      actor_1_name  \
# 0             La La Land        2016   30000000  151101803      Ryan Gosling
# 1               Zootopia        2016  150000000  341268248  Ginnifer Goodwin
# 2                   Lion        2016   12000000   51738905         Dev Patel
# 3                Arrival        2016   47000000  100546139         Amy Adams
# 4  Manchester by the Sea        2016    9000000   47695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes45A Votes45AM  \
# ...

# %%
top5_trio = movies.sort_values("ActorTrio_max_FBlikes", ascending = False)[:5]

# %%
top5_trio.style.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_c4674_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Title</th>
#       <th class="col_heading level0 col1" >title_year</th>
#       <th class="col_heading level0 col2" >budget</th>
#       <th class="col_heading level0 col3" >Gross</th>
#       <th class="col_heading level0 col4" >actor_1_name</th>
#       <th class="col_heading level0 col5" >actor_2_name</th>
#       <th class="col_heading level0 col6" >actor_3_name</th>
#       <th class="col_heading level0 col7" >actor_1_facebook_likes</th>
#       <th class="col_heading level0 col8" >actor_2_facebook_likes</th>
#       <th class="col_heading level0 col9" >actor_3_facebook_likes</th>
#       <th class="col_heading level0 col10" >IMDb_rating</th>
#       <th class="col_heading level0 col11" >genre_1</th>
#       <th class="col_heading level0 col12" >genre_2</th>
#       <th class="col_heading level0 col13" >genre_3</th>
# ...

# %%
plt.figure(figsize= [10,6])
sns.distplot(movies["Runtime"], bins = 15)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
classificaçãoR = movies[movies["content_rating"] == "R"].sort_values("CVotesU18", ascending = False)[["Title", "CVotesU18"]][:10]
classificaçãoR
# Out:
#                                               Title  CVotesU18
# 47                                         Deadpool       4598
# 36                          The Wolf of Wall Street       3622
# 35                                 Django Unchained       3250
# 29                               Mad Max: Fury Road       3159
# 95                                         Whiplash       2878
# 31                                     The Revenant       2619
# 40                                   Shutter Island       2321
# 43                                        Gone Girl       2286
# 65                         The Grand Budapest Hotel       2083
# 72  Birdman or (The Unexpected Virtue of Ignorance)       1891
