# %% [markdown]
# <a href="https://colab.research.google.com/github/Reinaldos/Reinaldos/blob/main/C%C3%B3pia_de_Projeto_5_OFICIAL_PRO_GITHUB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #<font color = black> **Projeto Módulo 05 - Grupo 04**
# ###<font color = black>**Data Analytics - Turma 12 - Resilia**

# %% [markdown]
# # **<font color = #87CEEB > Análise exploratória relacionada a Cota para o Exercício da Atividade Parlamentar dos anos de 2019, 2020 e 2021**
#
# ###<font color = orange> **Fonte de Dados Utilizada:**
#
# *   Site oficial da câmara dos deputados - [Portal](https://www2.camara.leg.br/transparencia/cota-para-exercicio-da-atividade-parlamentar/dados-abertos-cota-parlamentar)
# *   Base de Dados CEAP referente aos anos de 2019, 2020 e 2021.

# %% [markdown]
# #<font color = #87CEEB> **1. O que é CEAP?**

# %% [markdown]
# ![camara.jfif](data:image/jpeg;base64,...)
#
#
# A Cota para o Exercício da Atividade Parlamentar (CEAP), instituída pelo Ato da Mesa n. 43/2009, destina-se a custear gastos exclusivamente vinculados ao exercício do mandato, observados os limites mensais estabelecidos de acordo com o estado de origem do parlamentar, atendendo uma série de despesas, entre elas:
#
# I - passagens aéreas;
#
# II - telefonia;
#
# III - serviços e produtos postais previstos nos contratos firmados pela Câmara dos Deputados, vedada a aquisição de selos e a aquisição e remessa de cartões postais;
#
# IV - manutenção de escritórios de apoio à atividade parlamentar, compreendendo: locação de imóveis; condomínio; IPTU e seguro contra incêndio; serviços de energia elétrica, água e esgoto; locação de móveis e equipamentos; material de expediente e suprimentos de informática; acesso à internet; assinatura de TV a cabo ou similar; locação ou aquisição de licença de uso de software;
#
# V - assinatura de publicações;
#
# VI - fornecimento de alimentação do parlamentar;
#
# VII - hospedagem, exceto do parlamentar no Distrito Federal;
#
# VIII - outras despesas com locomoção, contemplando: locação ou fretamento de aeronaves; locação ou fretamento de veículos automotores, locação ou fretamento de embarcações; serviço de táxi, pedágio e estacionamento, passagens terrestres, marítimas ou fluviais;
#
# IX - combustíveis e lubrificantes, até o limite inacumulável de R$ 6.000,00 (seis mil reais) mensais;
#
# X - serviços de segurança prestados por empresa especializada, até o limite inacumulável de R$ 8.700,00 (oito mil e setecentos reais) mensais;
#
# XI - contratação, para fins de apoio ao exercício do mandato parlamentar, de consultorias e trabalhos técnicos, permitidas pesquisas socioeconômicas;
#
# XII - divulgação da sua atividade parlamentar, exceto nos 120 (cento e vinte) dias anteriores à data das eleições de âmbito federal, estadual ou municipal, salvo se o deputado não for candidato à eleição.
#
# XIII - participação do parlamentar em cursos, palestras, seminários, simpósios, congressos ou eventos congêneres, realizados por instituição especializada, até o limite mensal inacumulável correspondente a 25% (vinte e cinco por cento) do valor da menor cota mensal fixada no Anexo do Ato da Mesa nº 43/2009;
#
# XIV - complementação do auxílio-moradia de que trata o Ato da Mesa n. 104/88, até o limite inacumulável de R$1.747,00 (um mil, setecentos e quarenta e sete reais) mensais.
#
# Fonte: https://www2.camara.leg.br/comunicacao/camara-noticias/camara-destaca/56a-legislatura/no-exercicio-do-mandato/cota-para-o-exercicio-da-atividade-parlamentar-ceap

# %% [markdown]
# ## IMPORTANDO AS BIBLIOTECAS NECESSÁRIAS

# %%
import pandas as pd #para ler, visualizar e printar infos do df
import matplotlib.pyplot as plt #para construir e customizar gráficos
import seaborn as sns #para visualizar uns gráficos
import numpy as np #numpy para auxiliar na análise
from sklearn.preprocessing import MinMaxScaler
import plotly.express as px
import json
from urllib.request import urlopen
import plotly.graph_objects as go
import plotly as pt
# %matplotlib inline

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## IMPORTANDO O DATASET DOS PARLAMENTARES DE 2019, 2020 e 2021.

# %%
dfparlamentar = pd.read_csv('/content/drive/My Drive/Ano-2019.csv', sep = ';')
dfparlamentar20 = pd.read_csv('/content/drive/My Drive/Ano-2020.csv', sep = ';')
DFparlamentar21 = pd.read_csv('/content/drive/My Drive/Ano-2021.csv', sep = ';')

# %% [markdown]
# Agora, vamos buscar mais informações dos dataframes acima:

# %%
df_parlamentar = pd.merge(dfparlamentar, dfparlamentar20, how='outer')
dfparlamentar = pd.merge(df_parlamentar, DFparlamentar21, how='outer')

# %% [markdown]
# ## Verificando a porcentagem de nulos por coluna

# %%
(dfparlamentar.isnull().sum() / dfparlamentar.shape[0]).sort_values(ascending=False)
# Out:
# vlrRestituicao               0.999345
# txtTrecho                    0.768810
# txtPassageiro                0.766889
# txtDescricaoEspecificacao    0.754857
# numRessarcimento             0.674452
# urlDocumento                 0.370587
# txtCNPJCPF                   0.042826
# datEmissao                   0.028173
# cpf                          0.003311
# ideCadastro                  0.003134
# nuCarteiraParlamentar        0.003134
# sgUF                         0.003134
# sgPartido                    0.003134
# txtFornecedor                0.000059
# numParcela                   0.000000
# numLote                      0.000000
# numMes                       0.000000
# nuDeputadoId                 0.000000
# ideDocumento                 0.000000
# numAno                       0.000000
# txNomeParlamentar            0.000000
# vlrLiquido                   0.000000
# vlrGlosa                     0.000000
# vlrDocumento                 0.000000
# txtNumero                    0.000000
# numEspecificacaoSubCota      0.000000
# txtDescricao                 0.000000
# numSubCota                   0.000000
# codLegislatura               0.000000
# nuLegislatura                0.000000
# indTipoDocumento             0.000000
# dtype: float64

# %%
(dfparlamentar20.isnull().sum() / dfparlamentar.shape[0]).sort_values(ascending=False)
# Out:
# vlrRestituicao               0.289471
# txtTrecho                    0.237649
# txtPassageiro                0.237237
# txtDescricaoEspecificacao    0.217784
# numRessarcimento             0.208445
# urlDocumento                 0.098031
# txtCNPJCPF                   0.021021
# datEmissao                   0.010650
# cpf                          0.000706
# ideCadastro                  0.000706
# nuCarteiraParlamentar        0.000706
# sgUF                         0.000706
# sgPartido                    0.000706
# txtFornecedor                0.000032
# numParcela                   0.000000
# numLote                      0.000000
# numMes                       0.000000
# nuDeputadoId                 0.000000
# ideDocumento                 0.000000
# numAno                       0.000000
# txNomeParlamentar            0.000000
# vlrLiquido                   0.000000
# vlrGlosa                     0.000000
# vlrDocumento                 0.000000
# txtNumero                    0.000000
# numEspecificacaoSubCota      0.000000
# txtDescricao                 0.000000
# numSubCota                   0.000000
# codLegislatura               0.000000
# nuLegislatura                0.000000
# indTipoDocumento             0.000000
# dtype: float64

# %%
(DFparlamentar21.isnull().sum() / dfparlamentar.shape[0]).sort_values(ascending=False)
# Out:
# vlrRestituicao               0.190070
# txtTrecho                    0.164317
# txtPassageiro                0.164083
# numRessarcimento             0.146495
# txtDescricaoEspecificacao    0.133424
# urlDocumento                 0.054326
# txtCNPJCPF                   0.015149
# datEmissao                   0.006412
# sgPartido                    0.000799
# sgUF                         0.000799
# nuCarteiraParlamentar        0.000799
# ideCadastro                  0.000799
# cpf                          0.000799
# nuDeputadoId                 0.000000
# numMes                       0.000000
# numLote                      0.000000
# ideDocumento                 0.000000
# numParcela                   0.000000
# numAno                       0.000000
# txNomeParlamentar            0.000000
# vlrLiquido                   0.000000
# vlrGlosa                     0.000000
# vlrDocumento                 0.000000
# txtNumero                    0.000000
# txtFornecedor                0.000000
# numEspecificacaoSubCota      0.000000
# txtDescricao                 0.000000
# numSubCota                   0.000000
# codLegislatura               0.000000
# nuLegislatura                0.000000
# indTipoDocumento             0.000000
# dtype: float64

# %% [markdown]
# VERIFICANDO OS TIPOS DE DADOS PRESENTES NAS COLUNAS

# %%
display(dfparlamentar.dtypes)
display(dfparlamentar20.dtypes)
display(DFparlamentar21.dtypes)
# Out:
# txNomeParlamentar             object
# cpf                          float64
# ideCadastro                  float64
# nuCarteiraParlamentar        float64
# nuLegislatura                  int64
# sgUF                          object
# sgPartido                     object
# codLegislatura                 int64
# numSubCota                     int64
# txtDescricao                  object
# numEspecificacaoSubCota        int64
# txtDescricaoEspecificacao     object
# txtFornecedor                 object
# txtCNPJCPF                    object
# txtNumero                     object
# indTipoDocumento               int64
# datEmissao                    object
# vlrDocumento                 float64
# vlrGlosa                     float64
# vlrLiquido                   float64
# numMes                         int64
# numAno                         int64
# numParcela                     int64
# txtPassageiro                 object
# txtTrecho                     object
# numLote                        int64
# numRessarcimento             float64
# vlrRestituicao               float64
# nuDeputadoId                   int64
# ideDocumento                   int64
# urlDocumento                  object
# dtype: object
# txNomeParlamentar             object
# cpf                          float64
# ideCadastro                  float64
# nuCarteiraParlamentar        float64
# nuLegislatura                  int64
# sgUF                          object
# sgPartido                     object
# codLegislatura                 int64
# numSubCota                     int64
# txtDescricao                  object
# numEspecificacaoSubCota        int64
# txtDescricaoEspecificacao     object
# txtFornecedor                 object
# txtCNPJCPF                    object
# txtNumero                     object
# indTipoDocumento               int64
# datEmissao                    object
# vlrDocumento                 float64
# vlrGlosa                     float64
# vlrLiquido                   float64
# numMes                         int64
# numAno                         int64
# numParcela                     int64
# txtPassageiro                 object
# txtTrecho                     object
# numLote                        int64
# numRessarcimento             float64
# vlrRestituicao               float64
# nuDeputadoId                   int64
# ideDocumento                   int64
# urlDocumento                  object
# dtype: object
# txNomeParlamentar             object
# cpf                          float64
# ideCadastro                  float64
# nuCarteiraParlamentar        float64
# nuLegislatura                  int64
# sgUF                          object
# sgPartido                     object
# codLegislatura                 int64
# numSubCota                     int64
# txtDescricao                  object
# numEspecificacaoSubCota        int64
# txtDescricaoEspecificacao     object
# txtFornecedor                 object
# txtCNPJCPF                    object
# txtNumero                     object
# indTipoDocumento               int64
# datEmissao                    object
# vlrDocumento                 float64
# vlrGlosa                     float64
# vlrLiquido                   float64
# numMes                         int64
# numAno                         int64
# numParcela                     int64
# txtPassageiro                 object
# txtTrecho                     object
# numLote                        int64
# numRessarcimento             float64
# vlrRestituicao               float64
# nuDeputadoId                   int64
# ideDocumento                   int64
# urlDocumento                  object
# dtype: object

# %% [markdown]
# PODEMOS OBSERVAR QUE OS DATAFRAMES POSSUEM OS MESMOS TIPOS DE DADOS NAS MESMAS COLUNAS ISSO OS TORNA COMPATÍVEIS E NOS PERMITE UNI-LOS PARA FAZER UMA LIMPEZA MAIS PRECISA E OBJETIVA

# %%
dfparlamentarcompleto2 = pd.concat([dfparlamentar ,dfparlamentar20 ,DFparlamentar21])

# %%
dfparlamentarcompleto1 = pd.concat([dfparlamentar ,dfparlamentar20 ,DFparlamentar21])
dfparlamentarcompleto1
# Out:
#           txNomeParlamentar           cpf  ideCadastro  nuCarteiraParlamentar  \
# 0                LID.GOV-CD           NaN          NaN                    NaN
# 1                LID.GOV-CD           NaN          NaN                    NaN
# 2                LID.GOV-CD           NaN          NaN                    NaN
# 3                LID.GOV-CD           NaN          NaN                    NaN
# 4                LID.GOV-CD           NaN          NaN                    NaN
# ...                     ...           ...          ...                    ...
# 105600  Henrique do Paraíso  3.470995e+10     217036.0                  588.0
# 105601  Henrique do Paraíso  3.470995e+10     217036.0                  588.0
# 105602  Henrique do Paraíso  3.470995e+10     217036.0                  588.0
# 105603  Henrique do Paraíso  3.470995e+10     217036.0                  588.0
# 105604        DaLua do Rota  5.117259e+10     217330.0                  590.0
#
#         nuLegislatura sgUF     sgPartido  codLegislatura  numSubCota  \
# 0                2015  NaN           NaN              55          13
# 1                2019  NaN           NaN              56          13
# 2                2019  NaN           NaN              56          13
# 3                2019  NaN           NaN              56          13
# 4                2019  NaN           NaN              56          13
# ...               ...  ...           ...             ...         ...
# 105600           2019   SP  REPUBLICANOS              56           5
# 105601           2019   SP  REPUBLICANOS              56           5
# 105602           2019   SP  REPUBLICANOS              56           5
# 105603           2019   SP  REPUBLICANOS              56          10
# 105604           2019   AP           PSC              56          10
#
#                                       txtDescricao  ...  numAno numParcela  \
# 0       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# 1       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# 2       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# 3       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# 4       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# ...                                            ...  ...     ...        ...
# 105600        DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.  ...    2021          0
# 105601        DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.  ...    2021          0
# 105602        DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.  ...    2021          0
# 105603                                   TELEFONIA  ...    2021          0
# 105604                                   TELEFONIA  ...    2021          0
#
#        txtPassageiro txtTrecho  numLote  numRessarcimento vlrRestituicao  \
# 0                NaN       NaN  1554246               NaN            NaN
# 1                NaN       NaN  1570078               NaN            NaN
# 2                NaN       NaN  1570503               NaN            NaN
# 3                NaN       NaN  1579375               NaN            NaN
# 4                NaN       NaN  1590980               NaN            NaN
# ...              ...       ...      ...               ...            ...
# 105600           NaN       NaN  1781785               NaN            NaN
# 105601           NaN       NaN  1785880               NaN            NaN
# 105602           NaN       NaN  1782000               NaN            NaN
# 105603           NaN       NaN        0               0.0            NaN
# 105604           NaN       NaN        0               0.0            NaN
#
#         nuDeputadoId  ideDocumento  \
# 0               2812       6738121
# 1               2812       6769606
# 2               2812       6771099
# 3               2812       6793690
# 4               2812       6821674
# ...              ...           ...
# 105600          3486       7228378
# 105601          3486       7237484
# 105602          3486       7228945
# 105603          3486             0
# 105604          3487             0
#
#                                              urlDocumento
# 0       http://camara.leg.br/cota-parlamentar/nota-fis...
# 1       http://camara.leg.br/cota-parlamentar/nota-fis...
# 2       http://camara.leg.br/cota-parlamentar/nota-fis...
# 3       http://camara.leg.br/cota-parlamentar/nota-fis...
# 4       http://camara.leg.br/cota-parlamentar/nota-fis...
# ...                                                   ...
# 105600  https://www.camara.leg.br/cota-parlamentar/doc...
# 105601  https://www.camara.leg.br/cota-parlamentar/doc...
# 105602  https://www.camara.leg.br/cota-parlamentar/doc...
# 105603                                                NaN
# 105604                                                NaN
#
# [822008 rows x 31 columns]

# %% [markdown]
# FAZENDO A VERIFICAÇÃO DE COLUNAS E POSSÍVEIS ERROS

# %%
dfparlamentarcompleto1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 822008 entries, 0 to 105604
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   txNomeParlamentar          822008 non-null  object
#  1   cpf                        819333 non-null  float64
#  2   ideCadastro                819431 non-null  float64
#  3   nuCarteiraParlamentar      819431 non-null  float64
#  4   nuLegislatura              822008 non-null  int64
#  5   sgUF                       819431 non-null  object
#  6   sgPartido                  819431 non-null  object
#  7   codLegislatura             822008 non-null  int64
#  8   numSubCota                 822008 non-null  int64
#  9   txtDescricao               822008 non-null  object
#  10  numEspecificacaoSubCota    822008 non-null  int64
#  11  txtDescricaoEspecificacao  207589 non-null  object
#  12  txtFornecedor              821957 non-null  object
#  13  txtCNPJCPF                 778126 non-null  object
#  14  txtNumero                  822008 non-null  object
#  15  indTipoDocumento           822008 non-null  int64
#  16  datEmissao                 796880 non-null  object
#  17  vlrDocumento               822008 non-null  float64
#  18  vlrGlosa                   822008 non-null  float64
#  19  vlrLiquido                 822008 non-null  float64
#  20  numMes                     822008 non-null  int64
#  21  numAno                     822008 non-null  int64
#  22  numParcela                 822008 non-null  int64
#  23  txtPassageiro              173068 non-null  object
#  24  txtTrecho                  171642 non-null  object
#  25  numLote                    822008 non-null  int64
#  26  numRessarcimento           250181 non-null  float64
#  27  vlrRestituicao             487 non-null     float64
#  28  nuDeputadoId               822008 non-null  int64
#  29  ideDocumento               822008 non-null  int64
#  30  urlDocumento               531513 non-null  object
# dtypes: float64(8), int64(11), object(12)
# memory usage: 200.7+ MB

# %% [markdown]
# Todos os dataframes possuem o mesmo número de colunas, isso permite utilizar um código com a função drop(retirada) para retirar as colunas que não serão necessárias para a análise

# %%
dfparlamentarcompleto1.columns
# Out:
# Index(['txNomeParlamentar', 'cpf', 'ideCadastro', 'nuCarteiraParlamentar',
#        'nuLegislatura', 'sgUF', 'sgPartido', 'codLegislatura', 'numSubCota',
#        'txtDescricao', 'numEspecificacaoSubCota', 'txtDescricaoEspecificacao',
#        'txtFornecedor', 'txtCNPJCPF', 'txtNumero', 'indTipoDocumento',
#        'datEmissao', 'vlrDocumento', 'vlrGlosa', 'vlrLiquido', 'numMes',
#        'numAno', 'numParcela', 'txtPassageiro', 'txtTrecho', 'numLote',
#        'numRessarcimento', 'vlrRestituicao', 'nuDeputadoId', 'ideDocumento',
#        'urlDocumento'],
#       dtype='object')

# %% [markdown]
# De acordo com as perguntas solicitadas, vamos manter somente as colunas necessárias para realizar a análise:

# %%
dfparlamentarcompleto1.drop(['ideCadastro', 'nuCarteiraParlamentar',
       'nuLegislatura', 'codLegislatura',
       'numEspecificacaoSubCota',
       'txtFornecedor', 'txtCNPJCPF', 'txtNumero', 'indTipoDocumento',
       'numParcela','numLote',
       'numRessarcimento','nuDeputadoId', 'ideDocumento',
       'urlDocumento'],axis='columns', inplace = True)

# %%
dfparlamentarcompleto = dfparlamentarcompleto1

# %%
dfparlamentarcompleto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 822008 entries, 0 to 105604
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   txNomeParlamentar          822008 non-null  object
#  1   cpf                        819333 non-null  float64
#  2   sgUF                       819431 non-null  object
#  3   sgPartido                  819431 non-null  object
#  4   numSubCota                 822008 non-null  int64
#  5   txtDescricao               822008 non-null  object
#  6   txtDescricaoEspecificacao  207589 non-null  object
#  7   datEmissao                 796880 non-null  object
#  8   vlrDocumento               822008 non-null  float64
#  9   vlrGlosa                   822008 non-null  float64
#  10  vlrLiquido                 822008 non-null  float64
#  11  numMes                     822008 non-null  int64
#  12  numAno                     822008 non-null  int64
#  13  txtPassageiro              173068 non-null  object
#  14  txtTrecho                  171642 non-null  object
#  15  vlrRestituicao             487 non-null     float64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 106.6+ MB

# %% [markdown]
# # Convertendo a coluna "datEmissao" do tipo 'Object' para o tipo 'Datetime'

# %%
dfparlamentarcompleto['datEmissao'] = pd.to_datetime(dfparlamentarcompleto['datEmissao'], format = '%Y/%m/%d')

# %% [markdown]
# Como foi observado através da função .info(), o formato da coluna 'datEmissao' estava originalmente como do tipo 'Object' e esse formato não permite sua utilização em cálculos envolvendo datas, sendo assim convertido para o tipo 'Datetime'.

# %% [markdown]
# Depois de concatenar os 3 dataframes e retirar as colunas dispensáveis, ficamos com apenas 16 colunas:

# %%
dfparlamentarcompleto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 822008 entries, 0 to 105604
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   txNomeParlamentar          822008 non-null  object
#  1   cpf                        819333 non-null  float64
#  2   sgUF                       819431 non-null  object
#  3   sgPartido                  819431 non-null  object
#  4   numSubCota                 822008 non-null  int64
#  5   txtDescricao               822008 non-null  object
#  6   txtDescricaoEspecificacao  207589 non-null  object
#  7   datEmissao                 796880 non-null  datetime64[ns]
#  8   vlrDocumento               822008 non-null  float64
#  9   vlrGlosa                   822008 non-null  float64
#  10  vlrLiquido                 822008 non-null  float64
#  11  numMes                     822008 non-null  int64
#  12  numAno                     822008 non-null  int64
#  13  txtPassageiro              173068 non-null  object
#  14  txtTrecho                  171642 non-null  object
#  15  vlrRestituicao             487 non-null     float64
# dtypes: datetime64[ns](1), float64(5), int64(3), object(7)
# memory usage: 106.6+ MB

# %% [markdown]
# ## Organizando os dados Not a Number (NaN)

# %%
sem_partido_sem_uf = dfparlamentarcompleto[dfparlamentarcompleto['sgUF'].isnull()][['txNomeParlamentar', 'sgUF', 'sgPartido','vlrLiquido']]
sem_partido_sem_uf
# Out:
#     txNomeParlamentar sgUF sgPartido  vlrLiquido
# 0          LID.GOV-CD  NaN       NaN      111.30
# 1          LID.GOV-CD  NaN       NaN      117.19
# 2          LID.GOV-CD  NaN       NaN      120.15
# 3          LID.GOV-CD  NaN       NaN      151.18
# 4          LID.GOV-CD  NaN       NaN      119.90
# ..                ...  ...       ...         ...
# 439            LIDMIN  NaN       NaN     4000.00
# 440            LIDMIN  NaN       NaN      137.97
# 441            LIDMIN  NaN       NaN      175.18
# 442            LIDMIN  NaN       NaN     3800.00
# 443            LIDMIN  NaN       NaN     3800.00
#
# [2577 rows x 4 columns]

# %% [markdown]
# ##Atribuindo os partidos correspondentes as despesas relacionadas apenas às lideranças

# %%
dfparlamentarcompleto['sgPartido'] = np.where(dfparlamentarcompleto['txNomeParlamentar'] == "LIDERANÇA DO PSL", 'PSL', dfparlamentarcompleto.sgPartido)
dfparlamentarcompleto['sgPartido'] = np.where(dfparlamentarcompleto['txNomeParlamentar'] == "LIDERANÇA DO PT", 'PT', dfparlamentarcompleto.sgPartido)
dfparlamentarcompleto['sgPartido'] = np.where(dfparlamentarcompleto['txNomeParlamentar'] == "LIDERANÇA DO PTB", 'PTB', dfparlamentarcompleto.sgPartido) 
dfparlamentarcompleto['sgPartido'] = np.where(dfparlamentarcompleto['txNomeParlamentar'] == "LIDERANÇA DO PSDB", 'PSDB', dfparlamentarcompleto.sgPartido)
dfparlamentarcompleto['sgPartido'] = np.where(dfparlamentarcompleto['txNomeParlamentar'] == "LIDERANÇA DO PODEMOS", 'PODEMOS', dfparlamentarcompleto.sgPartido)
dfparlamentarcompleto['sgPartido'] = np.where(dfparlamentarcompleto['txNomeParlamentar'] == "LIDERANÇA DO SOLIDARIEDADE", 'SOLIDARIEDADE', dfparlamentarcompleto.sgPartido)
dfparlamentarcompleto['sgPartido'] = np.where(dfparlamentarcompleto['txNomeParlamentar'] == "LIDERANÇA DO PSD", 'PSD', dfparlamentarcompleto.sgPartido)
dfparlamentarcompleto['sgPartido'] = np.where(dfparlamentarcompleto['txNomeParlamentar'] == "LIDERANÇA DO NOVO", 'NOVO', dfparlamentarcompleto.sgPartido)
dfparlamentarcompleto['sgPartido'] = np.where(dfparlamentarcompleto['txNomeParlamentar'] == "LIDERANÇA DO DEMOCRATAS", 'DEMOCRATAS', dfparlamentarcompleto.sgPartido)
dfparlamentarcompleto['sgPartido'] = np.where(dfparlamentarcompleto['txNomeParlamentar'] == "LIDERANÇA DO CIDADANIA", 'CIDADANIA', dfparlamentarcompleto.sgPartido)
dfparlamentarcompleto['sgPartido'] = np.where(dfparlamentarcompleto['txNomeParlamentar'] == "LIDERANÇA DO AVANTE", 'AVANTE', dfparlamentarcompleto.sgPartido)
dfparlamentarcompleto['sgPartido'] = np.where(dfparlamentarcompleto['txNomeParlamentar'] == "LIDERANÇA DO PDT", 'PDT', dfparlamentarcompleto.sgPartido)
dfparlamentarcompleto['sgPartido'] = np.where(dfparlamentarcompleto['txNomeParlamentar'] == "LIDERANÇA DO PSOL", 'PSOL', dfparlamentarcompleto.sgPartido)
dfparlamentarcompleto['sgPartido'] = np.where(dfparlamentarcompleto['txNomeParlamentar'] == "LIDERANÇA DO PROGRESSISTAS", 'PROGRESSISTAS', dfparlamentarcompleto.sgPartido)
dfparlamentarcompleto['sgPartido'] = np.where(dfparlamentarcompleto['txNomeParlamentar'] == "LIDERANÇA DO PARTIDO REPUBLICANO DA ORDEM SOCIAL", 'SOCIAL', dfparlamentarcompleto.sgPartido)

# %%
dfparlamentarcompleto
# Out:
#           txNomeParlamentar           cpf sgUF     sgPartido  numSubCota  \
# 0                LID.GOV-CD           NaN  NaN           NaN          13
# 1                LID.GOV-CD           NaN  NaN           NaN          13
# 2                LID.GOV-CD           NaN  NaN           NaN          13
# 3                LID.GOV-CD           NaN  NaN           NaN          13
# 4                LID.GOV-CD           NaN  NaN           NaN          13
# ...                     ...           ...  ...           ...         ...
# 105600  Henrique do Paraíso  3.470995e+10   SP  REPUBLICANOS           5
# 105601  Henrique do Paraíso  3.470995e+10   SP  REPUBLICANOS           5
# 105602  Henrique do Paraíso  3.470995e+10   SP  REPUBLICANOS           5
# 105603  Henrique do Paraíso  3.470995e+10   SP  REPUBLICANOS          10
# 105604        DaLua do Rota  5.117259e+10   AP           PSC          10
#
#                                       txtDescricao txtDescricaoEspecificacao  \
# 0       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       NaN
# 1       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       NaN
# 2       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       NaN
# 3       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       NaN
# 4       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       NaN
# ...                                            ...                       ...
# 105600        DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                       NaN
# 105601        DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                       NaN
# 105602        DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                       NaN
# 105603                                   TELEFONIA                       NaN
# 105604                                   TELEFONIA                       NaN
#
#        datEmissao  vlrDocumento  vlrGlosa  vlrLiquido  numMes  numAno  \
# 0      2019-01-16        111.30       0.0      111.30       1    2019
# 1      2019-02-04        117.19       0.0      117.19       2    2019
# 2      2019-02-25        120.15       0.0      120.15       2    2019
# 3      2019-03-28        151.18       0.0      151.18       3    2019
# 4      2019-05-07        119.90       0.0      119.90       5    2019
# ...           ...           ...       ...         ...     ...     ...
# 105600 2021-07-28       5000.00       0.0     5000.00       7    2021
# 105601 2021-08-11       7000.00       0.0     7000.00       8    2021
# 105602 2021-07-29       4000.00       0.0     4000.00       7    2021
# 105603        NaT          1.10       0.0        1.10       7    2021
# 105604        NaT          1.08       0.0        1.08       7    2021
#
#        txtPassageiro txtTrecho  vlrRestituicao
# 0                NaN       NaN             NaN
# 1                NaN       NaN             NaN
# 2                NaN       NaN             NaN
# 3                NaN       NaN             NaN
# 4                NaN       NaN             NaN
# ...              ...       ...             ...
# 105600           NaN       NaN             NaN
# 105601           NaN       NaN             NaN
# 105602           NaN       NaN             NaN
# 105603           NaN       NaN             NaN
# 105604           NaN       NaN             NaN
#
# [822008 rows x 16 columns]

# %%
parlamentar = dfparlamentarcompleto
parlamentar
# Out:
#           txNomeParlamentar           cpf sgUF     sgPartido  numSubCota  \
# 0                LID.GOV-CD           NaN  NaN           NaN          13
# 1                LID.GOV-CD           NaN  NaN           NaN          13
# 2                LID.GOV-CD           NaN  NaN           NaN          13
# 3                LID.GOV-CD           NaN  NaN           NaN          13
# 4                LID.GOV-CD           NaN  NaN           NaN          13
# ...                     ...           ...  ...           ...         ...
# 105600  Henrique do Paraíso  3.470995e+10   SP  REPUBLICANOS           5
# 105601  Henrique do Paraíso  3.470995e+10   SP  REPUBLICANOS           5
# 105602  Henrique do Paraíso  3.470995e+10   SP  REPUBLICANOS           5
# 105603  Henrique do Paraíso  3.470995e+10   SP  REPUBLICANOS          10
# 105604        DaLua do Rota  5.117259e+10   AP           PSC          10
#
#                                       txtDescricao txtDescricaoEspecificacao  \
# 0       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       NaN
# 1       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       NaN
# 2       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       NaN
# 3       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       NaN
# 4       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       NaN
# ...                                            ...                       ...
# 105600        DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                       NaN
# 105601        DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                       NaN
# 105602        DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                       NaN
# 105603                                   TELEFONIA                       NaN
# 105604                                   TELEFONIA                       NaN
#
#        datEmissao  vlrDocumento  vlrGlosa  vlrLiquido  numMes  numAno  \
# 0      2019-01-16        111.30       0.0      111.30       1    2019
# 1      2019-02-04        117.19       0.0      117.19       2    2019
# 2      2019-02-25        120.15       0.0      120.15       2    2019
# 3      2019-03-28        151.18       0.0      151.18       3    2019
# 4      2019-05-07        119.90       0.0      119.90       5    2019
# ...           ...           ...       ...         ...     ...     ...
# 105600 2021-07-28       5000.00       0.0     5000.00       7    2021
# 105601 2021-08-11       7000.00       0.0     7000.00       8    2021
# 105602 2021-07-29       4000.00       0.0     4000.00       7    2021
# 105603        NaT          1.10       0.0        1.10       7    2021
# 105604        NaT          1.08       0.0        1.08       7    2021
#
#        txtPassageiro txtTrecho  vlrRestituicao
# 0                NaN       NaN             NaN
# 1                NaN       NaN             NaN
# 2                NaN       NaN             NaN
# 3                NaN       NaN             NaN
# 4                NaN       NaN             NaN
# ...              ...       ...             ...
# 105600           NaN       NaN             NaN
# 105601           NaN       NaN             NaN
# 105602           NaN       NaN             NaN
# 105603           NaN       NaN             NaN
# 105604           NaN       NaN             NaN
#
# [822008 rows x 16 columns]

# %%
parlamentar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 822008 entries, 0 to 105604
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   txNomeParlamentar          822008 non-null  object
#  1   cpf                        819333 non-null  float64
#  2   sgUF                       819431 non-null  object
#  3   sgPartido                  821885 non-null  object
#  4   numSubCota                 822008 non-null  int64
#  5   txtDescricao               822008 non-null  object
#  6   txtDescricaoEspecificacao  207589 non-null  object
#  7   datEmissao                 796880 non-null  datetime64[ns]
#  8   vlrDocumento               822008 non-null  float64
#  9   vlrGlosa                   822008 non-null  float64
#  10  vlrLiquido                 822008 non-null  float64
#  11  numMes                     822008 non-null  int64
#  12  numAno                     822008 non-null  int64
#  13  txtPassageiro              173068 non-null  object
#  14  txtTrecho                  171642 non-null  object
#  15  vlrRestituicao             487 non-null     float64
# dtypes: datetime64[ns](1), float64(5), int64(3), object(7)
# memory usage: 106.6+ MB

# %%
parlamentar.count()
# Out:
# txNomeParlamentar            822008
# cpf                          819333
# sgUF                         819431
# sgPartido                    821885
# numSubCota                   822008
# txtDescricao                 822008
# txtDescricaoEspecificacao    207589
# datEmissao                   796880
# vlrDocumento                 822008
# vlrGlosa                     822008
# vlrLiquido                   822008
# numMes                       822008
# numAno                       822008
# txtPassageiro                173068
# txtTrecho                    171642
# vlrRestituicao                  487
# dtype: int64

# %%
parlamentar = dfparlamentar[['txNomeParlamentar', 'sgUF']]
parlamentar
# Out:
#           txNomeParlamentar sgUF
# 0                LID.GOV-CD  NaN
# 1                LID.GOV-CD  NaN
# 2                LID.GOV-CD  NaN
# 3                LID.GOV-CD  NaN
# 4                LID.GOV-CD  NaN
# ...                     ...  ...
# 555495  Henrique do Paraíso   SP
# 555496  Henrique do Paraíso   SP
# 555497  Henrique do Paraíso   SP
# 555498  Henrique do Paraíso   SP
# 555499        DaLua do Rota   AP
#
# [555500 rows x 2 columns]

# %%
parlamentardropado = dfparlamentar.drop_duplicates()
parlamentardropado
# Out:
#           txNomeParlamentar           cpf  ideCadastro  nuCarteiraParlamentar  \
# 0                LID.GOV-CD           NaN          NaN                    NaN
# 1                LID.GOV-CD           NaN          NaN                    NaN
# 2                LID.GOV-CD           NaN          NaN                    NaN
# 3                LID.GOV-CD           NaN          NaN                    NaN
# 4                LID.GOV-CD           NaN          NaN                    NaN
# ...                     ...           ...          ...                    ...
# 555495  Henrique do Paraíso  3.470995e+10     217036.0                  588.0
# 555496  Henrique do Paraíso  3.470995e+10     217036.0                  588.0
# 555497  Henrique do Paraíso  3.470995e+10     217036.0                  588.0
# 555498  Henrique do Paraíso  3.470995e+10     217036.0                  588.0
# 555499        DaLua do Rota  5.117259e+10     217330.0                  590.0
#
#         nuLegislatura sgUF     sgPartido  codLegislatura  numSubCota  \
# 0                2015  NaN           NaN              55          13
# 1                2019  NaN           NaN              56          13
# 2                2019  NaN           NaN              56          13
# 3                2019  NaN           NaN              56          13
# 4                2019  NaN           NaN              56          13
# ...               ...  ...           ...             ...         ...
# 555495           2019   SP  REPUBLICANOS              56           5
# 555496           2019   SP  REPUBLICANOS              56           5
# 555497           2019   SP  REPUBLICANOS              56           5
# 555498           2019   SP  REPUBLICANOS              56          10
# 555499           2019   AP           PSC              56          10
#
#                                       txtDescricao  ...  numAno numParcela  \
# 0       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# 1       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# 2       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# 3       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# 4       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR  ...    2019          0
# ...                                            ...  ...     ...        ...
# 555495        DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.  ...    2021          0
# 555496        DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.  ...    2021          0
# 555497        DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.  ...    2021          0
# 555498                                   TELEFONIA  ...    2021          0
# 555499                                   TELEFONIA  ...    2021          0
#
#        txtPassageiro txtTrecho  numLote  numRessarcimento vlrRestituicao  \
# 0                NaN       NaN  1554246               NaN            NaN
# 1                NaN       NaN  1570078               NaN            NaN
# 2                NaN       NaN  1570503               NaN            NaN
# 3                NaN       NaN  1579375               NaN            NaN
# 4                NaN       NaN  1590980               NaN            NaN
# ...              ...       ...      ...               ...            ...
# 555495           NaN       NaN  1781785               NaN            NaN
# 555496           NaN       NaN  1785880               NaN            NaN
# 555497           NaN       NaN  1782000               NaN            NaN
# 555498           NaN       NaN        0               0.0            NaN
# 555499           NaN       NaN        0               0.0            NaN
#
#         nuDeputadoId  ideDocumento  \
# 0               2812       6738121
# 1               2812       6769606
# 2               2812       6771099
# 3               2812       6793690
# 4               2812       6821674
# ...              ...           ...
# 555495          3486       7228378
# 555496          3486       7237484
# 555497          3486       7228945
# 555498          3486             0
# 555499          3487             0
#
#                                              urlDocumento
# 0       http://camara.leg.br/cota-parlamentar/nota-fis...
# 1       http://camara.leg.br/cota-parlamentar/nota-fis...
# 2       http://camara.leg.br/cota-parlamentar/nota-fis...
# 3       http://camara.leg.br/cota-parlamentar/nota-fis...
# 4       http://camara.leg.br/cota-parlamentar/nota-fis...
# ...                                                   ...
# 555495  https://www.camara.leg.br/cota-parlamentar/doc...
# 555496  https://www.camara.leg.br/cota-parlamentar/doc...
# 555497  https://www.camara.leg.br/cota-parlamentar/doc...
# 555498                                                NaN
# 555499                                                NaN
#
# [555500 rows x 31 columns]

# %%
dfparlamentarcompleto1[['txNomeParlamentar','sgUF']]
dfparlamentarcompleto1
# Out:
#           txNomeParlamentar           cpf sgUF     sgPartido  numSubCota  \
# 0                LID.GOV-CD           NaN  NaN           NaN          13
# 1                LID.GOV-CD           NaN  NaN           NaN          13
# 2                LID.GOV-CD           NaN  NaN           NaN          13
# 3                LID.GOV-CD           NaN  NaN           NaN          13
# 4                LID.GOV-CD           NaN  NaN           NaN          13
# ...                     ...           ...  ...           ...         ...
# 105600  Henrique do Paraíso  3.470995e+10   SP  REPUBLICANOS           5
# 105601  Henrique do Paraíso  3.470995e+10   SP  REPUBLICANOS           5
# 105602  Henrique do Paraíso  3.470995e+10   SP  REPUBLICANOS           5
# 105603  Henrique do Paraíso  3.470995e+10   SP  REPUBLICANOS          10
# 105604        DaLua do Rota  5.117259e+10   AP           PSC          10
#
#                                       txtDescricao txtDescricaoEspecificacao  \
# 0       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       NaN
# 1       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       NaN
# 2       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       NaN
# 3       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       NaN
# 4       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       NaN
# ...                                            ...                       ...
# 105600        DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                       NaN
# 105601        DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                       NaN
# 105602        DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                       NaN
# 105603                                   TELEFONIA                       NaN
# 105604                                   TELEFONIA                       NaN
#
#        datEmissao  vlrDocumento  vlrGlosa  vlrLiquido  numMes  numAno  \
# 0      2019-01-16        111.30       0.0      111.30       1    2019
# 1      2019-02-04        117.19       0.0      117.19       2    2019
# 2      2019-02-25        120.15       0.0      120.15       2    2019
# 3      2019-03-28        151.18       0.0      151.18       3    2019
# 4      2019-05-07        119.90       0.0      119.90       5    2019
# ...           ...           ...       ...         ...     ...     ...
# 105600 2021-07-28       5000.00       0.0     5000.00       7    2021
# 105601 2021-08-11       7000.00       0.0     7000.00       8    2021
# 105602 2021-07-29       4000.00       0.0     4000.00       7    2021
# 105603        NaT          1.10       0.0        1.10       7    2021
# 105604        NaT          1.08       0.0        1.08       7    2021
#
#        txtPassageiro txtTrecho  vlrRestituicao
# 0                NaN       NaN             NaN
# 1                NaN       NaN             NaN
# 2                NaN       NaN             NaN
# 3                NaN       NaN             NaN
# 4                NaN       NaN             NaN
# ...              ...       ...             ...
# 105600           NaN       NaN             NaN
# 105601           NaN       NaN             NaN
# 105602           NaN       NaN             NaN
# 105603           NaN       NaN             NaN
# 105604           NaN       NaN             NaN
#
# [822008 rows x 16 columns]

# %% [markdown]
# ##Eliminamos todos os nomes duplicados da coluna txNomeParlamentar utilizando o .drop_duplicate().

# %%
parlamentar = dfparlamentarcompleto.drop_duplicates()
parlamentar
# Out:
#           txNomeParlamentar           cpf sgUF     sgPartido  numSubCota  \
# 0                LID.GOV-CD           NaN  NaN           NaN          13
# 1                LID.GOV-CD           NaN  NaN           NaN          13
# 2                LID.GOV-CD           NaN  NaN           NaN          13
# 3                LID.GOV-CD           NaN  NaN           NaN          13
# 4                LID.GOV-CD           NaN  NaN           NaN          13
# ...                     ...           ...  ...           ...         ...
# 555495  Henrique do Paraíso  3.470995e+10   SP  REPUBLICANOS           5
# 555496  Henrique do Paraíso  3.470995e+10   SP  REPUBLICANOS           5
# 555497  Henrique do Paraíso  3.470995e+10   SP  REPUBLICANOS           5
# 555498  Henrique do Paraíso  3.470995e+10   SP  REPUBLICANOS          10
# 555499        DaLua do Rota  5.117259e+10   AP           PSC          10
#
#                                       txtDescricao txtDescricaoEspecificacao  \
# 0       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       NaN
# 1       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       NaN
# 2       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       NaN
# 3       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       NaN
# 4       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       NaN
# ...                                            ...                       ...
# 555495        DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                       NaN
# 555496        DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                       NaN
# 555497        DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                       NaN
# 555498                                   TELEFONIA                       NaN
# 555499                                   TELEFONIA                       NaN
#
#        datEmissao  vlrDocumento  vlrGlosa  vlrLiquido  numMes  numAno  \
# 0      2019-01-16        111.30       0.0      111.30       1    2019
# 1      2019-02-04        117.19       0.0      117.19       2    2019
# 2      2019-02-25        120.15       0.0      120.15       2    2019
# 3      2019-03-28        151.18       0.0      151.18       3    2019
# 4      2019-05-07        119.90       0.0      119.90       5    2019
# ...           ...           ...       ...         ...     ...     ...
# 555495 2021-07-28       5000.00       0.0     5000.00       7    2021
# 555496 2021-08-11       7000.00       0.0     7000.00       8    2021
# 555497 2021-07-29       4000.00       0.0     4000.00       7    2021
# 555498        NaT          1.10       0.0        1.10       7    2021
# 555499        NaT          1.08       0.0        1.08       7    2021
#
#        txtPassageiro txtTrecho  vlrRestituicao
# 0                NaN       NaN             NaN
# 1                NaN       NaN             NaN
# 2                NaN       NaN             NaN
# 3                NaN       NaN             NaN
# 4                NaN       NaN             NaN
# ...              ...       ...             ...
# 555495           NaN       NaN             NaN
# 555496           NaN       NaN             NaN
# 555497           NaN       NaN             NaN
# 555498           NaN       NaN             NaN
# 555499           NaN       NaN             NaN
#
# [528731 rows x 16 columns]

# %% [markdown]
# ## Análise Exploratória para a resolução das questões predefinidas:

# %% [markdown]
# ### Nesta seção, consta a resolução das questões solicitadas para a atividade de análise exploratória dos gastos parlamentares. <p> As questões podem também ser conferidas na rubrica da atividade.</p>
# <hr>

# %% [markdown]
# **Questões:**
# 1. Como se comportam os gastos com cotas parlamentares ao longo
# do tempo? Existe alguma tendência de aumento ou redução desse
# custo?
# 2. Qual a média de gastos por parlamentar?
# 3. Quais foram os parlamentares que mais e que menos consumiram
# recursos?
# 4. Quais são as categorias de despesas mais onerosas dentre os
# recursos destinados às cotas parlamentares?
# 5. Quais são os trechos de viagem mais recorrentes entre as despesas
# de viagem?
# 6. Qual a média de gastos por estado?
# 7. Qual é o valor total de gastos por estado?
# 8. Quais estados têm maior número de representantes?
# 9. Há alguma correlação entre a quantidade de parlamentares por
# estado e o valor total dos gastos?
# 10. Qual a média de gastos por partido?
# 11. Quais são os partidos que mais e que menos consumiram a
# cota parlamentar?
# 12. Há alguma correlação entre a quantidade de parlamentares
# por partido e o valor total dos gastos?
#
# **Questões extras:**
#
# 13. A média total de gastos parlamentares durante o período analisado
# 14. O partido que mais teve gastos em viagens
# 15. A média de gastos de viagens por partido

# %% [markdown]
# ## 1 - Como se comportam os gastos com cotas parlamentares ao longo do tempo?
# ><b>Existe alguma tendência de aumento ou redução desse custo?</b>

# %% [markdown]
# ><b>Obs.:</b> Utilizado como referência a coluna 'vlrLiquido' conforme discrimina o Dicionário de Dados:
#      <p>O seu conteúdo representa o valor líquido do documento fiscal ou do documento que deu causa à despesa
#      e será calculado pela diferença entre o Valor do Documento e o Valor da Glosa. <p>É este valor que será
#      debitado da cota do deputado. Caso o débito seja do Tipo Telefonia e o valor seja igual a zero, significa
#      que a despesa foi franqueada.

# %% [markdown]
# ## 1.1 - Obtendo as despesas do período (2019 a 2021)

# %% [markdown]
# Aqui a opção foi usar o método dt.to_period('M') para agrupar os períodos por mês para facilitar a visualização

# %%
despesas_por_mes = dfparlamentarcompleto.groupby(dfparlamentarcompleto['datEmissao'].dt.to_period('M'))['vlrLiquido'].sum().reset_index()

despesas_por_mes['mes'] = [ '2018-11', '2018-12', '2019-01', '2019-02', '2019-03',
             '2019-04', '2019-05', '2019-06', '2019-07', '2019-08', '2019-09',
             '2019-10', '2019-11', '2019-12', '2020-01', '2020-02', '2020-03',
             '2020-04', '2020-05', '2020-06', '2020-07', '2020-08', '2020-09',
             '2020-10', '2020-11', '2020-12', '2021-01', '2021-02', '2021-03',
             '2021-04', '2021-05', '2021-06', '2021-07', '2021-08', '2021-09']

# %% [markdown]
# Obs. para plotar o gráfico o agrupamento por período não foi aceito, então foi criada a coluna mês para identificar o período.

# %% [markdown]
# Quais são as categorias de despesas mais onerosas dentre os recursos destinados às cotas parlamentares?
# Quais são os trechos de viagem mais recorrentes entre as despesas de viagem?
# Qual a média de gastos por estado?

# %% [markdown]
# ## 1.2 - Representação gráfica das despesas ao longo do período:

# %%
date = despesas_por_mes['mes']

value = despesas_por_mes["vlrLiquido"] / 1000000

fig, ax = plt.subplots(figsize=(18, 6))

# Adiconando títulos
plt.xlabel("Mês")
plt.ylabel("Valor em milhões de reais")
plt.grid()
# rotacionar das datas
fig.autofmt_xdate()

sns.barplot(x = date, y = value)

# %% [markdown]
# <hr>
# <a id="q_02"></a>

# %% [markdown]
# ## 2.0 - Qual a média de gastos por parlamentar?

# %%
# somando o valor total por deputado
a = dfparlamentarcompleto[['txNomeParlamentar', 'vlrLiquido']].drop_duplicates().groupby('txNomeParlamentar').sum().reset_index()

#contando quantos meses cada parlamentar ficou atuante
b = dfparlamentarcompleto[['txNomeParlamentar','numMes','numAno']].drop_duplicates().groupby('txNomeParlamentar').count().reset_index()

# juntando os dados
media_gastos = a.merge(b, left_on='txNomeParlamentar', right_on='txNomeParlamentar')

# criando uma coluna com a média de gastos por mês atuante
media_gastos['media_mes'] = (media_gastos.vlrLiquido / media_gastos.numMes)


media_gastos
# Out:
#         txNomeParlamentar  vlrLiquido  numMes  numAno     media_mes
# 0       ABEL MESQUITA JR.    45888.19       1       1  45888.190000
# 1          ADAIL CARNEIRO    42249.14       1       1  42249.140000
# 2    ADALBERTO CAVALCANTI    37422.25       1       1  37422.250000
# 3    ADELMO CARNEIRO LEÃO    36059.69       2       2  18029.845000
# 4         ADELSON BARRETO    20214.53       1       1  20214.530000
# ..                    ...         ...     ...     ...           ...
# 841              Zé Silva   479167.89      32      32  14973.996563
# 842              Zé Vitor   451472.62      31      31  14563.632903
# 843            Átila Lins   798359.23      32      32  24948.725937
# 844            Átila Lira   279728.84      31      31   9023.510968
# 845        Áurea Carolina   323426.25      30      30  10780.875000
#
# [846 rows x 5 columns]

# %%
sns.barplot(x="media_mes", y="txNomeParlamentar", data=media_gastos.sort_values(by='media_mes', ascending=False)[:10])
print()

# %%
desp_media_parlamentar = dfparlamentarcompleto[['txNomeParlamentar','sgPartido', 'vlrLiquido']].groupby(['txNomeParlamentar', 'sgPartido']).mean().sort_values('vlrLiquido',ascending=False).round(2)

desp_media_parlamentar.rename(columns={'vlrLiquido':'Despesa Média R$'}, inplace=True)

desp_media_parlamentar = desp_media_parlamentar.head()

desp_media_parlamentar.style.format({'Despesa Média R$':'R$ {:.2F}'}).background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_f3e8b_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_f3e8b_row1_col0 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_f3e8b_row2_col0 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_f3e8b_row3_col0, #T_f3e8b_row4_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_f3e8b_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Despesa Média R$</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >txNomeParlamentar</th>
#       <th class="index_name level1" >sgPartido</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3e8b_level0_row0" class="row_heading level0 row0" >JOSÉ REINALDO</th>
#       <th id="T_f3e8b_level1_row0" class="row_heading level1 row0" >PSDB</th>
#       <td id="T_f3e8b_row0_col0" class="data row0 col0" >R$ 13452.61</td>
#     </tr>
#     <tr>
#       <th id="T_f3e8b_level0_row1" class="row_heading level0 row1" >ALBERTO FRAGA</th>
#       <th id="T_f3e8b_level1_row1" class="row_heading level1 row1" >DEM</th>
#       <td id="T_f3e8b_row1_col0" class="data row1 col0" >R$ 10214.52</td>
#     </tr>
#     <tr>
#       <th id="T_f3e8b_level0_row2" class="row_heading level0 row2" >DELEGADO FRANCISCHINI</th>
#       <th id="T_f3e8b_level1_row2" class="row_heading level1 row2" >PSL</th>
#       <td id="T_f3e8b_row2_col0" class="data row2 col0" >R$ 8975.94</td>
#     </tr>
#     <tr>
#       <th id="T_f3e8b_level0_row3" class="row_heading level0 row3" >HEULER CRUVINEL</th>
#       <th id="T_f3e8b_level1_row3" class="row_heading level1 row3" >PP</th>
#       <td id="T_f3e8b_row3_col0" class="data row3 col0" >R$ 8881.52</td>
#     </tr>
#     <tr>
#       <th id="T_f3e8b_level0_row4" class="row_heading level0 row4" >CÉSAR HALUM</th>
#       <th id="T_f3e8b_level1_row4" class="row_heading level1 row4" >PRB</th>
#       <td id="T_f3e8b_row4_col0" class="data row4 col0" >R$ 8865.13</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <hr>
# <a id="q_03"></a>

# %% [markdown]
# ## 3 - Quais foram os parlamentares que mais e que menos consumiram recursos?

# %% [markdown]
# ## 3.1 - Exibindo o Parlamentar que consumiu mais recursos no Período de 2019 a 2021:

# %%
desp_maxima_parlamentar = dfparlamentarcompleto[['txNomeParlamentar','sgPartido', 'vlrLiquido']].groupby(['txNomeParlamentar', 'sgPartido']).sum().sort_values('vlrLiquido',ascending=False).round(2)

desp_maxima_parlamentar.rename(columns={'vlrLiquido':'Despesas Máximas R$'}, inplace=True)

desp_maxima_parlamentar = desp_maxima_parlamentar.head()

desp_maxima_parlamentar.style.format({'Despesas Máximas R$':'R$ {:.2F}'}).background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_ad041_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_ad041_row1_col0 {
#   background-color: #fcab8f;
#   color: #000000;
# }
# #T_ad041_row2_col0 {
#   background-color: #fcbea5;
#   color: #000000;
# }
# #T_ad041_row3_col0 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_ad041_row4_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_ad041_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Despesas Máximas R$</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >txNomeParlamentar</th>
#       <th class="index_name level1" >sgPartido</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad041_level0_row0" class="row_heading level0 row0" >Jéssica Sales</th>
#       <th id="T_ad041_level1_row0" class="row_heading level1 row0" >MDB</th>
#       <td id="T_ad041_row0_col0" class="data row0 col0" >R$ 2293598.07</td>
#     </tr>
#     <tr>
#       <th id="T_ad041_level0_row1" class="row_heading level0 row1" >João Maia</th>
#       <th id="T_ad041_level1_row1" class="row_heading level1 row1" >PL</th>
#       <td id="T_ad041_row1_col0" class="data row1 col0" >R$ 2188042.36</td>
#     </tr>
#     <tr>
#       <th id="T_ad041_level0_row2" class="row_heading level0 row2" >Wellington Roberto</th>
#       <th id="T_ad041_level1_row2" class="row_heading level1 row2" >PL</th>
#       <td id="T_ad041_row2_col0" class="data row2 col0" >R$ 2179785.79</td>
#     </tr>
#     <tr>
#       <th id="T_ad041_level0_row3" class="row_heading level0 row3" >Silas Câmara</th>
#       <th id="T_ad041_level1_row3" class="row_heading level1 row3" >REPUBLICANOS</th>
#       <td id="T_ad041_row3_col0" class="data row3 col0" >R$ 2151622.67</td>
#     </tr>
#     <tr>
#       <th id="T_ad041_level0_row4" class="row_heading level0 row4" >Flaviano Melo</th>
#       <th id="T_ad041_level1_row4" class="row_heading level1 row4" >MDB</th>
#       <td id="T_ad041_row4_col0" class="data row4 col0" >R$ 2143425.91</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 3.1.1 - Variante com a maior despesa única de um parlamentar

# %%
desp_maxima_parlamentar = dfparlamentarcompleto[['txNomeParlamentar','sgPartido', 'vlrLiquido']].groupby(['txNomeParlamentar', 'sgPartido']).max().sort_values('vlrLiquido',ascending=False).round(2)

desp_maxima_parlamentar.rename(columns={'vlrLiquido':'Maior Despesa R$'}, inplace=True)

desp_maxima_parlamentar = desp_maxima_parlamentar.head()

desp_maxima_parlamentar.style.format({'Maior Despesa R$':'R$ {:.2F}'}).background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_7b743_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_7b743_row1_col0 {
#   background-color: #ab1016;
#   color: #f1f1f1;
# }
# #T_7b743_row2_col0 {
#   background-color: #af1117;
#   color: #f1f1f1;
# }
# #T_7b743_row3_col0 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_7b743_row4_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_7b743_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Maior Despesa R$</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >txNomeParlamentar</th>
#       <th class="index_name level1" >sgPartido</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b743_level0_row0" class="row_heading level0 row0" >Edmilson Rodrigues</th>
#       <th id="T_7b743_level1_row0" class="row_heading level1 row0" >PSOL</th>
#       <td id="T_7b743_row0_col0" class="data row0 col0" >R$ 151260.00</td>
#     </tr>
#     <tr>
#       <th id="T_7b743_level0_row1" class="row_heading level0 row1" >Weliton Prado</th>
#       <th id="T_7b743_level1_row1" class="row_heading level1 row1" >PROS</th>
#       <td id="T_7b743_row1_col0" class="data row1 col0" >R$ 145140.00</td>
#     </tr>
#     <tr>
#       <th id="T_7b743_level0_row2" class="row_heading level0 row2" >Rogério Correia</th>
#       <th id="T_7b743_level1_row2" class="row_heading level1 row2" >PT</th>
#       <td id="T_7b743_row2_col0" class="data row2 col0" >R$ 144640.00</td>
#     </tr>
#     <tr>
#       <th id="T_7b743_level0_row3" class="row_heading level0 row3" >Raimundo Costa</th>
#       <th id="T_7b743_level1_row3" class="row_heading level1 row3" >PL</th>
#       <td id="T_7b743_row3_col0" class="data row3 col0" >R$ 110000.00</td>
#     </tr>
#     <tr>
#       <th id="T_7b743_level0_row4" class="row_heading level0 row4" >Professora Dorinha Seabra Rezende</th>
#       <th id="T_7b743_level1_row4" class="row_heading level1 row4" >DEM</th>
#       <td id="T_7b743_row4_col0" class="data row4 col0" >R$ 109500.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 3.2 - Exibindo o Parlamentar consumiu menos recursos no Período de 2019 a 2021:

# %%
desp_minima_parlamentar = dfparlamentarcompleto[['txNomeParlamentar','sgPartido', 'vlrLiquido']].groupby(['txNomeParlamentar', 'sgPartido']).sum().sort_values('vlrLiquido',ascending=True).round(2)

desp_minima_parlamentar.rename(columns={'vlrLiquido':'Despesa Mínima R$'}, inplace=True)

desp_minima_parlamentar = desp_minima_parlamentar.head()

desp_minima_parlamentar.style.format({'Despesa Mínima R$':'R$ {:.2F}'}).background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_b49be_row0_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_b49be_row1_col0 {
#   background-color: #ee3a2c;
#   color: #f1f1f1;
# }
# #T_b49be_row2_col0 {
#   background-color: #820711;
#   color: #f1f1f1;
# }
# #T_b49be_row3_col0 {
#   background-color: #77040f;
#   color: #f1f1f1;
# }
# #T_b49be_row4_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b49be_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Despesa Mínima R$</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >txNomeParlamentar</th>
#       <th class="index_name level1" >sgPartido</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b49be_level0_row0" class="row_heading level0 row0" >Jorge Goetten</th>
#       <th id="T_b49be_level1_row0" class="row_heading level1 row0" >PL</th>
#       <td id="T_b49be_row0_col0" class="data row0 col0" >R$ -48805.40</td>
#     </tr>
#     <tr>
#       <th id="T_b49be_level0_row1" class="row_heading level0 row1" >Renato Queiroz</th>
#       <th id="T_b49be_level1_row1" class="row_heading level1 row1" >MDB</th>
#       <td id="T_b49be_row1_col0" class="data row1 col0" >R$ -18214.42</td>
#     </tr>
#     <tr>
#       <th id="T_b49be_level0_row2" class="row_heading level0 row2" >Felipe Carreras</th>
#       <th id="T_b49be_level1_row2" class="row_heading level1 row2" >PSB</th>
#       <td id="T_b49be_row2_col0" class="data row2 col0" >R$ -2782.19</td>
#     </tr>
#     <tr>
#       <th id="T_b49be_level0_row3" class="row_heading level0 row3" >FELIPE BORNIER</th>
#       <th id="T_b49be_level1_row3" class="row_heading level1 row3" >PROS</th>
#       <td id="T_b49be_row3_col0" class="data row3 col0" >R$ -1675.06</td>
#     </tr>
#     <tr>
#       <th id="T_b49be_level0_row4" class="row_heading level0 row4" >LUCIANA SANTOS</th>
#       <th id="T_b49be_level1_row4" class="row_heading level1 row4" >PCdoB</th>
#       <td id="T_b49be_row4_col0" class="data row4 col0" >R$ 0.49</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##4. Quais são as categorias de despesas mais onerosas dentre os recursos destinados às cotas parlamentares?

# %%
Maisonerosas = dfparlamentarcompleto.groupby('txtDescricaoEspecificacao').agg({'vlrDocumento': ['max']}).copy()
Maisonerosas
# Out:
#                           vlrDocumento
#                                    max
# txtDescricaoEspecificacao
# Aeronaves                      7771.00
# Embarcações                    6000.00
# Sem especificações             6018.77
# Veículos Automotores           9535.03

# %%
grafico_comparação = Maisonerosas.plot.barh(xlabel = 'Descrição dos gastos',figsize =(18,4),fontsize = 10)
plt.legend(fontsize = 15,loc = 0, bbox_to_anchor = (1,1))
grafico_comparação.grid()

# %% [markdown]
# ##5. Quais são os trechos de viagem mais recorrentes entre as despesas de viagem

# %% [markdown]
# ## **Legenda dos aeroportos:**
#
# 1.BSB = BRASÍLIA
#
# 2.CGH = SÃO PAULO (CONGONHAS)
#
# 3.SDU = RIO DE JANEIRO(SANTOS DUMONT)
#
# 4.CNF = MINAS GERAIS (BELO HORIZONTE)
#
# 5.SSA = BAHIA (SALVADOR)
#
# 6.REC = PERNAMBUCO (RECIFE)

# %%
trechosrecorrentes = dfparlamentarcompleto['txtTrecho'].value_counts()
dfTrechos = pd.DataFrame(trechosrecorrentes)
dfTrechos = dfTrechos.head(10)
graficotrecho = dfTrechos.plot.bar(figsize =(18,6),fontsize = 10, color = '#ffcbdb')

# %% [markdown]
# ##6. Qual a média de gastos por estado?

# %%
gastosporestado = dfparlamentarcompleto[['vlrDocumento','sgUF']]
gastosporestado
# Out:
#         vlrDocumento sgUF
# 0             111.30  NaN
# 1             117.19  NaN
# 2             120.15  NaN
# 3             151.18  NaN
# 4             119.90  NaN
# ...              ...  ...
# 105600       5000.00   SP
# 105601       7000.00   SP
# 105602       4000.00   SP
# 105603          1.10   SP
# 105604          1.08   AP
#
# [822008 rows x 2 columns]

# %%
gastos_por_estado_media = gastosporestado.groupby('sgUF').agg({'vlrDocumento':['mean']}).copy()

# %%
gastos_por_estado_media
# Out:
#      vlrDocumento
#              mean
# sgUF
# AC    1726.799864
# AL    1592.257655
# AM    1694.229228
# AP    2099.924947
# BA    1055.820422
# CE    1322.467427
# DF    1653.250952
# ES     994.353068
# GO    1335.003791
# MA    1463.716368
# MG     727.012870
# MS     963.151886
# MT     873.822147
# PA    1352.642323
# PB    1143.908445
# PE     911.941673
# PI    1635.152413
# PR     730.266382
# RJ     848.297759
# RN     896.022267
# RO     862.903974
# RR    1751.202326
# RS     590.043122
# SC     576.561460
# SE    1551.087875
# SP     731.442437
# TO     954.670781

# %%
dfGastos = pd.DataFrame(gastos_por_estado_media)
dfGastos = dfGastos.head(30)
graficogastos = dfGastos.plot.barh(figsize =(18,6),fontsize = 10, color = '#3a6332')

# %% [markdown]
# # 7 - Qual é o valor total de gastos por estado?

# %%
liq_valor_positivo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 521568 entries, 0 to 555499
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   txNomeParlamentar          521568 non-null  object
#  1   cpf                        519754 non-null  float64
#  2   sgUF                       519827 non-null  object
#  3   sgPartido                  519827 non-null  object
#  4   numSubCota                 521568 non-null  int64
#  5   txtDescricao               521568 non-null  object
#  6   txtDescricaoEspecificacao  136110 non-null  object
#  7   vlrDocumento               521568 non-null  float64
#  8   vlrGlosa                   521568 non-null  float64
#  9   vlrLiquido                 521568 non-null  float64
#  10  numMes                     521568 non-null  int64
#  11  numAno                     521568 non-null  int64
#  12  txtTrecho                  94860 non-null   object
#  13  vlrRestituicao             0 non-null       float64
# dtypes: float64(5), int64(3), object(6)
# memory usage: 59.7+ MB

# %%
parlamentar_drop_colunas = dfparlamentar.drop(columns=['ideCadastro', 'nuCarteiraParlamentar', 'nuLegislatura', 'numParcela', 'datEmissao', 'codLegislatura', 'numEspecificacaoSubCota', 'txtFornecedor', 'txtCNPJCPF', 'txtNumero', 'indTipoDocumento', 'txtPassageiro', 'numLote', 'numRessarcimento', 'nuDeputadoId', 'ideDocumento', 'urlDocumento'])
parlamentar_drop_colunas
# Out:
#           txNomeParlamentar           cpf sgUF     sgPartido  numSubCota  \
# 0                LID.GOV-CD           NaN  NaN           NaN          13
# 1                LID.GOV-CD           NaN  NaN           NaN          13
# 2                LID.GOV-CD           NaN  NaN           NaN          13
# 3                LID.GOV-CD           NaN  NaN           NaN          13
# 4                LID.GOV-CD           NaN  NaN           NaN          13
# ...                     ...           ...  ...           ...         ...
# 555495  Henrique do Paraíso  3.470995e+10   SP  REPUBLICANOS           5
# 555496  Henrique do Paraíso  3.470995e+10   SP  REPUBLICANOS           5
# 555497  Henrique do Paraíso  3.470995e+10   SP  REPUBLICANOS           5
# 555498  Henrique do Paraíso  3.470995e+10   SP  REPUBLICANOS          10
# 555499        DaLua do Rota  5.117259e+10   AP           PSC          10
#
#                                       txtDescricao txtDescricaoEspecificacao  \
# 0       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       NaN
# 1       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       NaN
# 2       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       NaN
# 3       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       NaN
# 4       FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR                       NaN
# ...                                            ...                       ...
# 555495        DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                       NaN
# 555496        DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                       NaN
# 555497        DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.                       NaN
# 555498                                   TELEFONIA                       NaN
# 555499                                   TELEFONIA                       NaN
#
#         vlrDocumento  vlrGlosa  vlrLiquido  numMes  numAno txtTrecho  \
# 0             111.30       0.0      111.30       1    2019       NaN
# 1             117.19       0.0      117.19       2    2019       NaN
# 2             120.15       0.0      120.15       2    2019       NaN
# 3             151.18       0.0      151.18       3    2019       NaN
# 4             119.90       0.0      119.90       5    2019       NaN
# ...              ...       ...         ...     ...     ...       ...
# 555495       5000.00       0.0     5000.00       7    2021       NaN
# 555496       7000.00       0.0     7000.00       8    2021       NaN
# 555497       4000.00       0.0     4000.00       7    2021       NaN
# 555498          1.10       0.0        1.10       7    2021       NaN
# 555499          1.08       0.0        1.08       7    2021       NaN
#
#         vlrRestituicao
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 555495             NaN
# 555496             NaN
# 555497             NaN
# 555498             NaN
# 555499             NaN
#
# [555500 rows x 14 columns]

# %%
liq_valor_positivo = parlamentar_drop_colunas[parlamentar_drop_colunas['vlrLiquido']>0]

# %% [markdown]
# ## 7.1 - Filtro da coluna vlLiquido exibindo somente o que for >0.

# %%
liq_valor_positivo = parlamentar_drop_colunas[parlamentar_drop_colunas['vlrLiquido']>0]

# %%
gasto_total_estado = liq_valor_positivo.groupby('sgUF').sum().sort_values('vlrLiquido', ascending=False).reset_index()

# %%
gasto_total_estado[['sgUF','vlrLiquido']].groupby(['sgUF']).sum().sort_values(by=['vlrLiquido'], ascending = False).reset_index()
# Out:
#    sgUF   vlrLiquido
# 0    SP  56018765.12
# 1    MG  44332329.78
# 2    BA  41814441.90
# 3    RJ  39462315.62
# 4    PR  28143234.00
# 5    RS  26809293.87
# 6    PE  24178001.35
# 7    CE  23773169.28
# 8    MA  19240191.49
# 9    PA  17817430.51
# 10   GO  14441132.16
# 11   PB  13108057.77
# 12   PI  10708322.35
# 13   AC  10668603.93
# 14   SC  10565669.91
# 15   AP   9571047.06
# 16   AM   9082025.81
# 17   AL   8850156.41
# 18   RR   8521271.37
# 19   SE   8448662.60
# 20   ES   8446763.27
# 21   TO   8354916.05
# 22   RN   8211288.78
# 23   MT   7370938.62
# 24   MS   7106284.94
# 25   RO   6267501.57
# 26   DF   4327628.33

# %%
gasto_total_estado[['sgUF','vlrLiquido']].groupby(['sgUF']).sum().sort_values(by=['vlrLiquido'], ascending = False).reset_index()
# Out:
#    sgUF   vlrLiquido
# 0    SP  56018765.12
# 1    MG  44332329.78
# 2    BA  41814441.90
# 3    RJ  39462315.62
# 4    PR  28143234.00
# 5    RS  26809293.87
# 6    PE  24178001.35
# 7    CE  23773169.28
# 8    MA  19240191.49
# 9    PA  17817430.51
# 10   GO  14441132.16
# 11   PB  13108057.77
# 12   PI  10708322.35
# 13   AC  10668603.93
# 14   SC  10565669.91
# 15   AP   9571047.06
# 16   AM   9082025.81
# 17   AL   8850156.41
# 18   RR   8521271.37
# 19   SE   8448662.60
# 20   ES   8446763.27
# 21   TO   8354916.05
# 22   RN   8211288.78
# 23   MT   7370938.62
# 24   MS   7106284.94
# 25   RO   6267501.57
# 26   DF   4327628.33

# %%
varVariavel = gasto_total_estado['vlrLiquido'] / 100000
varVariavel.round(2)
# Out:
# 0     560.19
# 1     443.32
# 2     418.14
# 3     394.62
# 4     281.43
# 5     268.09
# 6     241.78
# 7     237.73
# 8     192.40
# 9     178.17
# 10    144.41
# 11    131.08
# 12    107.08
# 13    106.69
# 14    105.66
# 15     95.71
# 16     90.82
# 17     88.50
# 18     85.21
# 19     84.49
# 20     84.47
# 21     83.55
# 22     82.11
# 23     73.71
# 24     71.06
# 25     62.68
# 26     43.28
# Name: vlrLiquido, dtype: float64

# %%
plt.figure(figsize=(14,7))
sns.set_style('darkgrid')
graf = sns.barplot(data = gasto_total_estado, x=varVariavel, y='sgUF', orient='h')
graf.set(xlabel = 'Valores Gastos * 100000', ylabel = 'Estados', title ='Gasto Total Parlamentares por Estado')
graf.set_yticklabels(labels = gasto_total_estado['sgUF'])
# Out:
# [Text(0, 0, 'SP'),
#  Text(0, 0, 'MG'),
#  Text(0, 0, 'BA'),
#  Text(0, 0, 'RJ'),
#  Text(0, 0, 'PR'),
#  Text(0, 0, 'RS'),
#  Text(0, 0, 'PE'),
#  Text(0, 0, 'CE'),
#  Text(0, 0, 'MA'),
#  Text(0, 0, 'PA'),
#  Text(0, 0, 'GO'),
#  Text(0, 0, 'PB'),
#  Text(0, 0, 'PI'),
#  Text(0, 0, 'AC'),
#  Text(0, 0, 'SC'),
#  Text(0, 0, 'AP'),
#  Text(0, 0, 'AM'),
#  Text(0, 0, 'AL'),
#  Text(0, 0, 'RR'),
#  Text(0, 0, 'SE'),
#  Text(0, 0, 'ES'),
#  Text(0, 0, 'TO'),
#  Text(0, 0, 'RN'),
#  Text(0, 0, 'MT'),
#  Text(0, 0, 'MS'),
#  Text(0, 0, 'RO'),
#  Text(0, 0, 'DF')]

# %% [markdown]
# # 8 - Quais estados têm maior número de representantes? *

# %%
dfparlamentar = dfparlamentar.query('vlrLiquido > 0')

# %%
representante_por_uf = parlamentar_drop_colunas[['txNomeParlamentar', 'sgUF']].drop_duplicates().reset_index()
representante_por_uf
# Out:
#       index        txNomeParlamentar sgUF
# 0         0               LID.GOV-CD  NaN
# 1        15      LIDERANÇA DO AVANTE  NaN
# 2        64   LIDERANÇA DO CIDADANIA  NaN
# 3       114  LIDERANÇA DO DEMOCRATAS  NaN
# 4       124        LIDERANÇA DO NOVO  NaN
# ..      ...                      ...  ...
# 841  555185                   Rafafá   PB
# 842  555279    Paulo Vicente Caleffi   RS
# 843  555374            Totonho Lopes   CE
# 844  555469      Henrique do Paraíso   SP
# 845  555499            DaLua do Rota   AP
#
# [846 rows x 3 columns]

# %%
plt.figure(figsize=(10,5))
sns.barplot(data = parlamentar_por_uf, x='sgUF', y='txNomeParlamentar', palette = "Oranges_r")
plt.xticks(rotation=90)
plt.xlabel('')
plt.ylabel('Quantidade de parlamentar por UF') # legenda lateral
# Out:
# Text(0, 0.5, 'Quantidade de parlamentar por UF')

# %% [markdown]
# # 9 - Há alguma correlação entre a quantidade de parlamentares por estado e o valor total dos gastos?

# %%
representante_por_uf = parlamentar_drop_colunas[['txNomeParlamentar', 'sgUF']].drop_duplicates().reset_index()

# %%
gasto_total_estado = liq_valor_positivo.groupby('sgUF').sum().sort_values('vlrLiquido', ascending=False).reset_index()

# %%
parlamentar_por_uf = representante_por_uf.groupby('sgUF').count().sort_values('txNomeParlamentar', ascending=False).reset_index()
parlamentar_por_uf.drop(columns = ['index'], inplace = True)
parlamentar_por_uf
# Out:
#    sgUF  txNomeParlamentar
# 0    SP                104
# 1    RJ                 82
# 2    MG                 81
# 3    BA                 56
# 4    RS                 47
# 5    PR                 46
# 6    CE                 39
# 7    PE                 38
# 8    MA                 34
# 9    SC                 30
# 10   GO                 27
# 11   PA                 27
# 12   PB                 20
# 13   ES                 17
# 14   MS                 16
# 15   MT                 15
# 16   DF                 15
# 17   PI                 15
# 18   AP                 15
# 19   AC                 14
# 20   AL                 14
# 21   AM                 14
# 22   RO                 13
# 23   RR                 13
# 24   RN                 13
# 25   SE                 12
# 26   TO                 12

# %%
parl_liq_estado = pd.merge(parlamentar_por_uf, gasto_total_estado, on = 'sgUF')
parl_liq_estado
# Out:
#    sgUF  txNomeParlamentar           cpf  numSubCota  vlrDocumento   vlrGlosa  \
# 0    SP                104  1.694832e+15    16439423   56282744.39  214041.99
# 1    RJ                 82  1.258920e+15    11674160   39676968.16  159295.89
# 2    MG                 81  2.304158e+15    11349030   44605662.58  209994.19
# 3    BA                 56  1.114234e+15     8957044   42074737.21  215105.68
# 4    RS                 47  1.880056e+15     6760552   27006226.84  134484.32
# 5    PR                 46  1.322274e+15     7491246   28345046.12  139216.67
# 6    CE                 39  7.656823e+14     5453703   23924760.69   92832.80
# 7    PE                 38  7.815938e+14     5679527   24316837.82  130746.33
# 8    MA                 34  5.740550e+14     3165590   19373234.95  120505.39
# 9    SC                 30  6.419661e+14     3167368   10623707.19   45184.10
# 10   GO                 27  2.987325e+14      412645   14497839.67   39794.52
# 11   PA                 27  2.963157e+14     3874926   17915992.66   84076.52
# 12   PB                 20  3.824597e+14     2109887   13152214.23   39807.93
# 13   ES                 17  3.838987e+14     1723499    8545468.58   55850.12
# 14   MS                 16  3.746450e+14     1357059    7172290.03   58531.14
# 15   MT                 15  2.246872e+14     1660490    7404857.92   28741.58
# 16   DF                 15  1.340136e+14      100334    4377144.76   21870.08
# 17   PI                 15  1.042729e+14     1654902   10781474.14   53233.99
# 18   AP                 15  2.184205e+14     1228641    9678045.32   98878.66
# 19   AC                 14  2.891996e+14     1380425   10734865.08   37778.85
# 20   AL                 14  1.827193e+14     1603573    9006133.26   29824.91
# 21   AM                 14  1.758299e+14     1472191    9099780.09   15172.06
# 22   RO                 13  3.336757e+14     1083861    6291933.33   22274.30
# 23   RR                 13  2.525045e+14     1251893    8547323.48   17831.32
# 24   RN                 13  1.640149e+14     1784033    8244226.51   25559.66
# 25   SE                 12  2.442501e+14     1654569    8506112.81   18104.12
# 26   TO                 12  2.079674e+14     1204092    8388391.67   27545.54
#
#      vlrLiquido  numMes     numAno  vlrRestituicao
# 0   56018765.12  480852  161273341             0.0
# 1   39462315.62  282061   94992215             0.0
# 2   44332329.78  387127  127831011             0.0
# 3   41814441.90  244971   82114974             0.0
# 4   26809293.87  284905   93666331             0.0
# 5   28143234.00  237590   80277548             0.0
# 6   23773169.28  107211   35640656             0.0
# 7   24178001.35  152115   51299730             0.0
# 8   19240191.49   79944   26503930             0.0
# 9   10565669.91  112245   37664421             0.0
# 10  14441132.16   70656   22770377             0.0
# 11  17817430.51   76131   25830474             0.0
# 12  13108057.77   73043   23945241             0.0
# 13   8446763.27   52099   17734735             0.0
# 14   7106284.94   46548   15503119             0.0
# 15   7370938.62   54555   18096095             0.0
# 16   4327628.33   17203    5653108             0.0
# 17  10708322.35   39349   13383947             0.0
# 18   9571047.06   26896    9243739             0.0
# 19  10668603.93   37607   12685680             0.0
# 20   8850156.41   33511   11198364             0.0
# 21   9082025.81   31187   10706325             0.0
# 22   6267501.57   43600   14453146             0.0
# 23   8521271.37   27645    9585012             0.0
# 24   8211288.78   57395   19090013             0.0
# 25   8448662.60   32601   11093750             0.0
# 26   8354916.05   54341   17636315             0.0

# %%
#Normalização em dataframe
scaler_01 = MinMaxScaler() 

dados_normalizados = scaler_01.fit_transform(parl_liq_estado[['txNomeParlamentar', 'vlrLiquido']])
dados_normalizados
# Out:
# array([[1.        , 1.        ],
#        [0.76086957, 0.67970429],
#        [0.75      , 0.773918  ],
#        [0.47826087, 0.72520776],
#        [0.38043478, 0.43492302],
#        [0.36956522, 0.460729  ],
#        [0.29347826, 0.37618714],
#        [0.2826087 , 0.38401889],
#        [0.23913043, 0.28849362],
#        [0.19565217, 0.12067913],
#        [0.16304348, 0.19565257],
#        [0.16304348, 0.26096935],
#        [0.08695652, 0.16986335],
#        [0.05434783, 0.07968745],
#        [0.04347826, 0.05375499],
#        [0.0326087 , 0.0588749 ],
#        [0.0326087 , 0.        ],
#        [0.0326087 , 0.12343884],
#        [0.0326087 , 0.10143748],
#        [0.02173913, 0.12267046],
#        [0.02173913, 0.08749136],
#        [0.02173913, 0.09197703],
#        [0.01086957, 0.03752816],
#        [0.01086957, 0.08112886],
#        [0.01086957, 0.07513204],
#        [0.        , 0.0797242 ],
#        [0.        , 0.0779106 ]])

# %% [markdown]
# ## 9.1 - Normalização em dataframe

# %%
dados_normalizados2 = pd.DataFrame(dados_normalizados)
dados_normalizados2.rename(columns={0:'Numero_de_representantes_uf', 1:'Total_de_Gastos'}, inplace=True)
dados_normalizados2
# Out:
#     Numero_de_representantes_uf  Total_de_Gastos
# 0                      1.000000         1.000000
# 1                      0.760870         0.679704
# 2                      0.750000         0.773918
# 3                      0.478261         0.725208
# 4                      0.380435         0.434923
# 5                      0.369565         0.460729
# 6                      0.293478         0.376187
# 7                      0.282609         0.384019
# 8                      0.239130         0.288494
# 9                      0.195652         0.120679
# 10                     0.163043         0.195653
# 11                     0.163043         0.260969
# 12                     0.086957         0.169863
# 13                     0.054348         0.079687
# 14                     0.043478         0.053755
# 15                     0.032609         0.058875
# 16                     0.032609         0.000000
# 17                     0.032609         0.123439
# 18                     0.032609         0.101437
# 19                     0.021739         0.122670
# 20                     0.021739         0.087491
# 21                     0.021739         0.091977
# 22                     0.010870         0.037528
# 23                     0.010870         0.081129
# 24                     0.010870         0.075132
# 25                     0.000000         0.079724
# 26                     0.000000         0.077911

# %% [markdown]
# ## 9.2 - Exibindo correlação muito alta já que 1 e 0,98 estão positivamente muito próximas.

# %%
dados_normalizados_var = dados_normalizados2.corr()
dados_normalizados_var
# Out:
#                              Numero_de_representantes_uf  Total_de_Gastos
# Numero_de_representantes_uf                     1.000000         0.972658
# Total_de_Gastos                                 0.972658         1.000000

# %% [markdown]
# ## 9.3 - Gráfico de correlação quantidade de parlamentares por estado x gasto total por estado.

# %%
sns.heatmap(dados_normalizados_var, 
        xticklabels= dados_normalizados_var.columns,
        yticklabels= dados_normalizados_var.columns, annot=True, cmap="PuOr", vmin=-1, vmax=1)
print()

# %% [markdown]
# # Questão 10

# %%
custosTodosPartidos = dfparlamentarcompleto[['sgPartido','vlrDocumento','sgUF','cpf']].dropna()
custoMedioPartidos = custosTodosPartidos.groupby("sgPartido").mean().reset_index().sort_values('vlrDocumento')
custoMedioPartidos
# Out:
#         sgPartido  vlrDocumento           cpf
# 4            NOVO    346.337077  1.219536e+10
# 1       CIDADANIA    651.057270  2.546522e+10
# 22            PSL    676.976717  2.936497e+10
# 18            PSB    789.848574  3.329282e+10
# 0          AVANTE    811.681297  4.438137e+10
# 26             PV    857.054714  5.905849e+10
# 24             PT    868.876304  2.852055e+10
# 3             MDB    910.565488  3.368590e+10
# 12             PP    928.095494  3.258363e+10
# 21           PSDB    949.343219  3.791037e+10
# 11           PODE    952.089250  2.071278e+10
# 23           PSOL    969.050430  1.036881e+10
# 20            PSD    977.939025  4.034517e+10
# 14            PPS    978.822232  2.169158e+10
# 25            PTB   1000.735064  5.222975e+10
# 6        PATRIOTA   1009.385836  2.752055e+10
# 8             PDT   1024.590737  3.478656e+10
# 5           PATRI   1064.531558  2.695879e+10
# 2             DEM   1066.303202  2.871470e+10
# 10             PL   1087.072828  2.836871e+10
# 15             PR   1097.437995  2.451400e+10
# 16            PRB   1187.840038  3.666123e+10
# 30  SOLIDARIEDADE   1192.676604  2.442627e+10
# 28   REPUBLICANOS   1213.253346  3.285861e+10
# 19            PSC   1285.156825  3.775532e+10
# 17           PROS   1295.605877  4.588886e+10
# 9             PHS   1295.671871  2.507361e+10
# 7           PCdoB   1304.100244  2.586829e+10
# 27           REDE   1362.585435  3.370457e+10
# 29        S.PART.   1865.031611  5.900488e+08
# 13            PPL   2246.287500  3.746803e+09

# %%
sns.set_theme(style="whitegrid")
ax = sns.barplot(x="sgPartido", y="vlrDocumento",data=custoMedioPartidos)
ax.figure.set_size_inches(18,6)
plt.xticks(rotation = 90)
ax.set_xlabel("Partidos", fontsize = 20)
ax.set_ylabel("Despesas(milhares de R$)", fontsize = 20)
ax.set(title = "Custo médio por partido")
# Out:
# [Text(0.5, 1.0, 'Custo médio por partido')]

# %%
x = dfparlamentarcompleto[['sgPartido','vlrDocumento','sgUF']].dropna().groupby('sgPartido').sum().sort_values(by='vlrDocumento',ascending = False)
x
# Out:
#                vlrDocumento
# sgPartido
# PT              87859621.64
# PSL             70292486.60
# PL              63518873.01
# PP              60178546.47
# REPUBLICANOS    52522358.58
# PSD             52479060.58
# MDB             51791358.13
# PSDB            48743236.11
# PDT             43229974.53
# DEM             42802537.03
# PSB             40532323.38
# SOLIDARIEDADE   21797507.61
# PTB             19324668.53
# PROS            16407213.59
# PODE            14780817.56
# PSC             13870697.61
# PCdoB           13837779.66
# AVANTE          11280478.19
# PSOL            10585906.90
# PATRIOTA         9054190.95
# CIDADANIA        8830289.75
# PV               4648664.77
# NOVO             2956849.56
# REDE             1456603.83
# PR               1224079.34
# S.PART.          1111558.84
# PRB               630743.06
# PPS               219225.91
# PHS               180098.39
# PATRI             163937.86
# PPL                44925.75

# %% [markdown]
# # Questão 11

# %%
x.plot(kind='bar')

# %% [markdown]
# # Questão 12

# %%
gastos_uftotal = dfparlamentarcompleto[['sgPartido' , 'vlrLiquido']].groupby('sgPartido').sum().sort_values('vlrLiquido', ascending = False).round(2)

gastos_uftotal.rename(columns = {'vlrLiquido':'Valor_Total'}, inplace = True)

gastos_uftotal = gastos_uftotal.reset_index()

parlamentares_uf = dfparlamentarcompleto[['txNomeParlamentar', 'sgPartido']].drop_duplicates()

parlamentares_uf = parlamentares_uf.groupby('sgPartido').count().sort_values('txNomeParlamentar', ascending = False)

parlamentares_uf.rename(columns = {'txNomeParlamentar':'Quantidade De Representantes'}, inplace = True)

parlamentares_uf = parlamentares_uf.reset_index()

maximo = parlamentares_uf['Quantidade De Representantes'].max()

# %%
y = np.array(gastos_uftotal['Valor_Total']/1000000)
x = np.array(gastos_uftotal.sgPartido)
plt.figure(figsize=(20,7))
plt.subplot(1,2,1)
plt.xticks(gastos_uftotal.index, rotation = 90)
plt.grid(axis= 'y')
plt.bar(x,y)
plt.title('Despesas em Milhões de Reais por Partido')
# Out:
# Text(0.5, 1.0, 'Despesas em Milhões de Reais por Partido')

# %%
x = np.array(parlamentares_uf.sgPartido)
y = np.array(parlamentares_uf['Quantidade De Representantes'])
plt.figure(figsize=(20,7))
plt.subplot(1,2,2)
plt.xticks(parlamentares_uf.index, rotation = 90)
plt.bar(x,y)
plt.grid(axis= 'x')
plt.title('Número de Deputado por Partido')
plt.show()

# %% [markdown]
# ## 13. A média total de gastos parlamentares durante o período analisado##

# %%
media_parlamentares = dfparlamentarcompleto['vlrDocumento'].mean()
media_parlamentares
# Out:
# 935.4984425333101

# %% [markdown]
# A média total de gastos parlamentares entre 2019 e 2021 foi de
# R$884.4121722591002.

# %% [markdown]
# ##14. O partido que mais teve gastos em viagens##

# %%
maiorGastoViagens = dfparlamentarcompleto.groupby('sgPartido')['vlrDocumento'].sum().sort_values(ascending=False).head(5).copy()
maiorGastoViagens
# Out:
# sgPartido
# PT     88508568.92
# PSL    70334802.14
# PL     63518873.01
# PP     60178546.47
# PSD    52648625.99
# Name: vlrDocumento, dtype: float64

# %%
partidos = maiorGastoViagens.filter('sgPartido')
despesas = maiorGastoViagens.filter('vlrDocumento')
plt.figure(figsize=(12,6))
plt.bar(partidos,despesas)

sg_Partidos = ['PT', 'PSL', 'PL' , 'PP', 'MDB']
vlr_Liquido = [ 53101273.58, 38739174.80, 36009565.01, 34429101.14, 31505872.66]
plt.bar(sg_Partidos, vlr_Liquido)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# O partido que mais teve gastos com viagens foi o Partido dos Trabalhadores (PT).
#
# O gráfico de barras permite visualizar os cinco partidos que mais gastaram com viagens.

# %% [markdown]
# ## 15. Qual é a média de gastos com viagens por partido?

# %%
maiorMediaGastopartido = dfparlamentarcompleto.groupby('sgPartido')['vlrDocumento'].mean().sort_values(ascending=False).copy
maiorMediaGastopartido
# Out:
# <bound method NDFrame.copy of sgPartido
# PROGRESSISTAS    6220.588235
# SOCIAL           2779.841159
# PPL              2246.287500
# S.PART.          1865.031611
# REDE             1362.585435
# PCdoB            1303.974714
# PHS              1295.671871
# PROS             1295.170002
# PSC              1285.156825
# REPUBLICANOS     1213.183623
# SOLIDARIEDADE    1188.194937
# PRB              1187.840038
# PR               1094.883131
# PL               1087.074892
# DEM              1066.171898
# PATRI            1064.531558
# PDT              1033.223024
# PATRIOTA         1009.385836
# PTB               991.943948
# PSD               977.853792
# PPS               974.337378
# PSOL              971.068789
# PODE              952.065543
# PSDB              948.760034
# PP                928.022491
# MDB               910.489217
# PT                868.872528
# PV                857.054714
# DEMOCRATAS        833.541500
# AVANTE            811.573451
# PODEMOS           795.990338
# PSB               789.842029
# PSL               676.999212
# CIDADANIA         651.467873
# NOVO              349.072116
# Name: vlrDocumento, dtype: float64>

# %%
maiorMediaGastopartido = dfparlamentarcompleto.groupby(['sgPartido']).agg({'vlrDocumento':['mean']}).copy()
maiorMediaGastopartido
# Out:
#               vlrDocumento
#                       mean
# sgPartido
# AVANTE          811.573451
# CIDADANIA       651.467873
# DEM            1066.171898
# DEMOCRATAS      833.541500
# MDB             910.489217
# NOVO            349.072116
# PATRI          1064.531558
# PATRIOTA       1009.385836
# PCdoB          1303.974714
# PDT            1033.223024
# PHS            1295.671871
# PL             1087.074892
# PODE            952.065543
# PODEMOS         795.990338
# PP              928.022491
# PPL            2246.287500
# PPS             974.337378
# PR             1094.883131
# PRB            1187.840038
# PROGRESSISTAS  6220.588235
# PROS           1295.170002
# PSB             789.842029
# PSC            1285.156825
# PSD             977.853792
# PSDB            948.760034
# PSL             676.999212
# PSOL            971.068789
# PT              868.872528
# PTB             991.943948
# PV              857.054714
# REDE           1362.585435
# REPUBLICANOS   1213.183623
# S.PART.        1865.031611
# SOCIAL         2779.841159
# SOLIDARIEDADE  1188.194937

# %%
maiorMediaGastopartido.plot(kind='bar', figsize=(20,7), title= 'A média de gastos com viagens por partido', color="red")

# %% [markdown]
# A média de gastos com viagens por partido pode ser analisada a partir do gráfio de barras.
#
# O partido Progressistas possui a maior média de gastos com viagens, enquanto o Partido Novo apresenta a menor.
